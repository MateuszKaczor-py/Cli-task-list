# %%
import json

def add_task(key, value):
    try:
        with open('Tasks.data.json', 'r') as file:
                tasks =json.load(file)
    except FileNotFoundError:
        tasks = {}
    tasknum = int(key)
    tasktodo = str(value)
    task = {

}
    task[tasknum] = tasktodo
    
    with open('tasks_data.json','w') as file:
        json.dump(task, file, indent=4)
    return f"Task was added {task}"

def update_task():
    return
def delete_task():
    return
print(add_task(1, 'Muszę wysprzątać'))
# Out:
# Task was added {1: 'Muszę wysprzątać'}
